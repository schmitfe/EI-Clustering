# %%
import sys
sys.path.append("/opt/app-root/src/drive/My Libraries/Cluster_Prob")
sys.path.append("/opt/app-root/src/brainscales2-demos.git")

# %%
import simulate_metastability_ensemble as ensemble

# %%
summary = ensemble.main([
      "--networks", "25",
      "--kappa", "0.0",
      "--simtime-ms", "150",
      "--outdir", "bs2_metastability_runs_kappa0",
      "--resume",
      "--raster-window-ms", "6",
  ])

# %%
summary = ensemble.main([
      "--networks", "25",
      "--kappa", "0.5",
      "--simtime-ms", "150",
      "--outdir", "bs2_metastability_runs_kappa0_5",
      "--resume",
      "--raster-window-ms", "6",
  ])

# %%
summary = ensemble.main([
      "--networks", "25",
      "--kappa", "1.",
      "--simtime-ms", "150",
      "--outdir", "bs2_metastability_runs_kappa1",
      "--resume",
      "--raster-window-ms", "6",
  ])
